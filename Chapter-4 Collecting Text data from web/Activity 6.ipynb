# %% [markdown]
# # Extracting information from an online HTML page

# %%
import requests 
from bs4 import BeautifulSoup

# %%
result = requests.get('https://en.wikipedia.org/wiki/Rabindranath_Tagore')

# %%
result
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(result.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Rabindranath Tagore - Wikipedia</title>
# ...

# %% [markdown]
# # List of heading under work section

# %%
print('List of Headings under work section - ')
print('')
for tag in soup.find_all('h3')[:7]: 
    if tag.find('span',attrs = {'class':'mw-headline'}):
        print(tag.get_text())
# Out:
# List of Headings under work section -
#
# Drama
# Short stories
# Novels
# Poetry
# Songs (Rabindra Sangeet)
# Art works
# Repudiation of knighthood

# %%
for tag in soup.find_all('h3')[8:]: 
    if tag.find('span',attrs = {'class':'mw-headline'}):
        print(tag.get_text())
# Out:
# Original
# Translated
# Bengali
# Hindi
# Primary
# Secondary
# Texts

# %% [markdown]
# # List of universities named

# %%
len(soup.find_all('ul'))
# Out:
# 116

# %%
preceding_text = soup.find('span',attrs={'id':'List_of_universities_and_university_buildings_named_after_him'})

# %%
ul = preceding_text.find_next()
for row in ul.find_all('a'):
    print(row.text)
# Out:
# Rabindra Bharati University
# Rabindranath Tagore International Institute of Cardiac Sciences
# Rabindra University
# [177]
# Rabindranath Tagore University, Hojai
# Rabindra Maitree University
# [178]
# Jahangirnagar University
# Islamic University
# Assam University
# Rabindranath Thakur Mahavidyalaya
# Tripura
